# %% [markdown]
# ## Blocket Car in pySpark
#
# ### Jonas Lundgren
# ### Last Updated: Jan 26, 2019
#
# ---
#
# ### Sources
#
# https://www.youtube.com/watch?v=XQgXKtPSzUI&t=0s&index=2&list=LLgrRgAlce_d0J02aHPrp4nA
#
# University of California, Santa Barbara: PSTAT 135/235, winter quarter 2019
#
# ### Explanation
# - Part 1: Webscraping of cars for sale in Skåne, Sweden from private sellers. Scraping is done from Swedish buy and sell site https://www.blocket.se/ using BeautifulSoup.
# - Part 2: Data preprocessing done using pySpark since I wanted to practice and was not necessary for a data set containing about 2500 rows (scraping done on Jan 26 2019). Visualizations are done using pandas and matplotlib.
# - Part 3: Continuing with cleaning data and feature engineering. (new scraping done on Feb 02 2019)
#
#
# #### Note:
# Formating of the webpage where the scraping was done could change if this is read at a later time.
#
# ---

# %% [markdown]
# ### Part 1
# #### Jan 26, 2019
# Loading packages used for webscraping.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Url to the site where scraping will be done.

# %%
my_url = 'https://www.blocket.se/malmo/bilar?ca=23_11&cg=1020&st=s&l=0&f=p&w=1'
client = requests.get(my_url).text

# %%
soup = BeautifulSoup(client, "html.parser")

# %% [markdown]
# The path in the html file we are interested in.

# %%
cars = soup.find_all('div', {'id': 'item_list'})[0].find_all('article')

# %% [markdown]
# Testing to scrape data from the second car on blocket to see if everything is ok

# %%
info = cars[1]
location = info.div.div.text
date = info.div.time.get('datetime')
title = info.div.find('a', {'class': 'item_link'}).text.replace(',', '|')

splited_info = info.div.p.text.split(' | ')

fuel = splited_info[0]
gear = splited_info[1]
dist = splited_info[2]
price = info.div.find('p', {'class' : 'list_price font-large'}).text

# %% [markdown]
# Testing to loop over all cars on the first page of cars in the wanted region. If the # signs are removed a file called "blocket_cars.csv" is stored containing the cars at the first page.

# %%
filename = "blocket_cars.csv"
#f = open(filename, "w")
headers = "date, title, dist, price, fuel, gear, location\n"
#f.write(headers)

for car in cars:
    info = car
   
    date = info.div.time.get('datetime')
    title = info.div.find('a', {'class': 'item_link'}).text.replace(',', '|')

    splited_info = info.div.p.text.split(' | ')

    fuel = splited_info[0]
    gear = splited_info[1]
    dist = splited_info[2]
    price = info.div.find('p', {'class' : 'list_price font-large'}).text
    location = info.div.div.text

    #f.write(date + "," + title + "," + dist + "," + price + "," + fuel + "," + gear + "," + location + "\n")
    
#f.close()

# %% [markdown]
# Here a file called "blocket_cars.csv" is created containing all cars in Skåne not from resellers is stored. The while loop loops over all pages on blocket with the search results we are interested in. At current time it was 52 pages. For every page we loop over the number of cars and store the data we are interseted in: date, title, dist, price, fuel, gear, location. The page number is printed to see how far the scraping process has passed.

# %%
filename = "blocket_cars.csv"
f = open(filename, "w")
headers = "date, title, dist, price, fuel, gear, location\n"
f.write(headers)
stop = 'NA'
i = 1

while(stop != 'Inga träffar i Bilar'):
    
    my_url = 'https://www.blocket.se/malmo/bilar?ca=23_11&cg=1020&st=s&l=0&f=p&w=1&o=' + str(i)

    client = requests.get(my_url).text

    soup = BeautifulSoup(client, "html.parser")
    
    try:
        stop = soup.find_all('div', {'class': 'ads_not_found col-xs-12'})[0].h3.text
    except:
        print('Page number: ' + str(i))
    
    cars = soup.find_all('div', {'id': 'item_list'})[0].find_all('article')
    
    for car in cars:
        info = car
        
        if(info.div.p.text == ''):
            break
        
        date = info.div.time.get('datetime')
        title = info.div.find('a', {'class': 'item_link'}).text.replace(',', '|')

        splited_info = info.div.p.text.split(' | ')
        
        fuel = splited_info[0]
        gear = splited_info[1]
        dist = splited_info[2]
        price = info.div.find('p', {'class' : 'list_price font-large'}).text
        location = info.div.div.text

        f.write(date + "," + title + "," + dist + "," + price + "," + fuel + "," + gear + "," + location + "\n")
    
    i = i+1
    
f.close()
# Out:
# Page number: 1
# Page number: 2
# Page number: 3
# Page number: 4
# Page number: 5
# Page number: 6
# Page number: 7
# Page number: 8
# Page number: 9
# Page number: 10
# Page number: 11
# Page number: 12
# Page number: 13
# Page number: 14
# Page number: 15
# Page number: 16
# Page number: 17
# Page number: 18
# Page number: 19
# Page number: 20
# Page number: 21
# Page number: 22
# Page number: 23
# Page number: 24
# Page number: 25
# Page number: 26
# Page number: 27
# Page number: 28
# Page number: 29
# Page number: 30
# Page number: 31
# Page number: 32
# Page number: 33
# Page number: 34
# Page number: 35
# Page number: 36
# Page number: 37
# Page number: 38
# Page number: 39
# Page number: 40
# Page number: 41
# Page number: 42
# Page number: 43
# Page number: 44
# Page number: 45
# Page number: 46
# Page number: 47
# Page number: 48
# Page number: 49
# Page number: 50
# Page number: 51
# Page number: 52
# Page number: 53

# %% [markdown]
# ### Part 2
#
# SparkSession is imported aswell as other spark packages

# %%
from pyspark.sql import SparkSession
import pyspark.sql.types as typ
from pyspark.sql.functions import *
from pyspark.sql import SQLContext
import pandas

spark = SparkSession \
    .builder \
    .master("local") \
    .appName("review_and_category_analytics") \
    .config("spark.executor.memory", '2g') \
    .config('spark.executor.cores', '2') \
    .config('spark.cores.max', '2') \
    .config("spark.driver.memory",'2g') \
    .getOrCreate()

sc = spark.sparkContext
sqlCtx = SQLContext(sc)

# %% [markdown]
# The data is read into a data frame called df.

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("ignoreLeadingWhiteSpace",'true')\
    .load("blocket_cars2019-03-21.csv")

# %% [markdown]
# The data frame df is saved.

# %%
df.cache()
# Out:
# DataFrame[date: string, title: string, dist: string, price: string, fuel: string, gear: string, location: string]

# %% [markdown]
# First 5 rows are displayed

# %%
df.show(5)
# Out:
# +-------------------+--------------------+-------------------+----------+------+-------+-----------+
# |               date|               title|               dist|     price|  fuel|   gear|   location|
# +-------------------+--------------------+-------------------+----------+------+-------+-----------+
# |2019-03-21 21:46:37|Cadillac Deville ...|  3 500 - 3 999 mil|229 000 kr|Bensin|Automat|      Ystad|
# |2019-03-21 21:46:15| Peugeot 206 1.4 -05|10 500 - 10 999 mil| 26 000 kr|Bensin|Manuell|       Höör|
# |2019-03-21 21:45:55|   Audi A3 1|6 L -05|23 000 - 23 499 mil| 29 000 kr|Bensin|Manuell|    Sydväst|
# |2019-03-21 21:45:26|Seat Ateca TSi 15...|  2 500 - 2 999 mil|225 000 kr|Bensin|Automat|Helsingborg|
# |2019-03-21 21:44:52| Volvo xc70 2.5T -05|27 000 - 27 499 mil| 28 000 kr|Bensin|Manuell|      Sjöbo|
# +-------------------+--------------------+-------------------+----------+------+-------+-----------+
# only showing top 5 rows

# %%
df.columns
# Out:
# ['date', 'title', 'dist', 'price', 'fuel', 'gear', 'location']

# %%
df.printSchema()
# Out:
# root
#  |-- date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- dist: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- fuel: string (nullable = true)
#  |-- gear: string (nullable = true)
#  |-- location: string (nullable = true)

# %% [markdown]
# Lower casing all caps in the the title.

# %%
df = df.withColumn('title', lower(df.title))

# %% [markdown]
# Removing the currency sign kr and the space in the price.

# %%
df = df\
        .withColumn('price', regexp_replace('price', ' kr', ''))\
        .withColumn('price', regexp_replace('price', ' ', ''))

# %% [markdown]
# Convering the price to int.

# %%
df = df.withColumn('price', df['price'].cast("int"))

# %% [markdown]
# Checking the results

# %%
df.show(5)
# Out:
# +-------------------+--------------------+-------------------+------+------+-------+-----------+
# |               date|               title|               dist| price|  fuel|   gear|   location|
# +-------------------+--------------------+-------------------+------+------+-------+-----------+
# |2019-03-21 21:46:37|cadillac deville ...|  3 500 - 3 999 mil|229000|Bensin|Automat|      Ystad|
# |2019-03-21 21:46:15| peugeot 206 1.4 -05|10 500 - 10 999 mil| 26000|Bensin|Manuell|       Höör|
# |2019-03-21 21:45:55|   audi a3 1|6 l -05|23 000 - 23 499 mil| 29000|Bensin|Manuell|    Sydväst|
# |2019-03-21 21:45:26|seat ateca tsi 15...|  2 500 - 2 999 mil|225000|Bensin|Automat|Helsingborg|
# |2019-03-21 21:44:52| volvo xc70 2.5t -05|27 000 - 27 499 mil| 28000|Bensin|Manuell|      Sjöbo|
# +-------------------+--------------------+-------------------+------+------+-------+-----------+
# only showing top 5 rows

# %% [markdown]
# Removing mil from the distance the car has traveled.

# %%
df = df.withColumn('dist', regexp_replace('dist', ' mil', ''))

# %% [markdown]
# Creating a split in the distance the car has traveled.

# %%
split_col = split(df['dist'], ' - ')

# %% [markdown]
# Creating 2 columns with distance range.

# %%
df = df.withColumn('from', split_col.getItem(0))
df = df.withColumn('to', split_col.getItem(1))

# %% [markdown]
# Converingt the distance to ints.

# %%
df = df.withColumn('from', regexp_replace('from', ' ', ''))
df = df.withColumn('from', df['from'].cast("int"))

df = df.withColumn('to', regexp_replace('to', ' ', ''))
df = df.withColumn('to', df['to'].cast("int"))

# %%
df.show(5)
# Out:
# +-------------------+--------------------+---------------+------+------+-------+-----------+-----+-----+
# |               date|               title|           dist| price|  fuel|   gear|   location| from|   to|
# +-------------------+--------------------+---------------+------+------+-------+-----------+-----+-----+
# |2019-03-21 21:46:37|cadillac deville ...|  3 500 - 3 999|229000|Bensin|Automat|      Ystad| 3500| 3999|
# |2019-03-21 21:46:15| peugeot 206 1.4 -05|10 500 - 10 999| 26000|Bensin|Manuell|       Höör|10500|10999|
# |2019-03-21 21:45:55|   audi a3 1|6 l -05|23 000 - 23 499| 29000|Bensin|Manuell|    Sydväst|23000|23499|
# |2019-03-21 21:45:26|seat ateca tsi 15...|  2 500 - 2 999|225000|Bensin|Automat|Helsingborg| 2500| 2999|
# |2019-03-21 21:44:52| volvo xc70 2.5t -05|27 000 - 27 499| 28000|Bensin|Manuell|      Sjöbo|27000|27499|
# +-------------------+--------------------+---------------+------+------+-------+-----------+-----+-----+
# only showing top 5 rows

# %% [markdown]
# Splitting the title to get the brand and model of car. The split is done in a sloppy way and there are several cars where the title was not on form: brand model ... This problem is ignored for now.

# %%
split_col = split(df['title'], ' ')

# %%
df = df.withColumn('brand', split_col.getItem(0))
df = df.withColumn('model', split_col.getItem(1))

# %%
df.show(5)
# Out:
# +-------------------+--------------------+---------------+------+------+-------+-----------+-----+-----+--------+-------+
# |               date|               title|           dist| price|  fuel|   gear|   location| from|   to|   brand|  model|
# +-------------------+--------------------+---------------+------+------+-------+-----------+-----+-----+--------+-------+
# |2019-03-21 21:46:37|cadillac deville ...|  3 500 - 3 999|229000|Bensin|Automat|      Ystad| 3500| 3999|cadillac|deville|
# |2019-03-21 21:46:15| peugeot 206 1.4 -05|10 500 - 10 999| 26000|Bensin|Manuell|       Höör|10500|10999| peugeot|    206|
# |2019-03-21 21:45:55|   audi a3 1|6 l -05|23 000 - 23 499| 29000|Bensin|Manuell|    Sydväst|23000|23499|    audi|     a3|
# |2019-03-21 21:45:26|seat ateca tsi 15...|  2 500 - 2 999|225000|Bensin|Automat|Helsingborg| 2500| 2999|    seat|  ateca|
# |2019-03-21 21:44:52| volvo xc70 2.5t -05|27 000 - 27 499| 28000|Bensin|Manuell|      Sjöbo|27000|27499|   volvo|   xc70|
# +-------------------+--------------------+---------------+------+------+-------+-----------+-----+-----+--------+-------+
# only showing top 5 rows

# %% [markdown]
# A new data frame called volvo is created with only the cars of the brand Volvo.

# %%
volvo = df.filter(df.brand == 'volvo')
volvo.show(10)
# Out:
# +-------------------+--------------------+---------------+------+------+-------+------------+-----+-----+-----+-----+
# |               date|               title|           dist| price|  fuel|   gear|    location| from|   to|brand|model|
# +-------------------+--------------------+---------------+------+------+-------+------------+-----+-----+-----+-----+
# |2019-03-21 21:44:52| volvo xc70 2.5t -05|27 000 - 27 499| 28000|Bensin|Manuell|       Sjöbo|27000|27499|volvo| xc70|
# |2019-03-21 20:36:07|volvo v90 d5 r-de...|  4 000 - 4 499|425000|Diesel|Automat|        Osby| 4000| 4499|volvo|  v90|
# |2019-03-21 19:45:07|volvo xc70 d4 mom...|  9 000 - 9 499|189900|Diesel|Automat|       Öster| 9000| 9499|volvo| xc70|
# |2019-03-21 18:21:58|volvo v50 t5 awd -04|16 000 - 16 499| 47000|Bensin|Manuell|  Simrishamn|16000|16499|volvo|  v50|
# |2019-03-21 17:44:41|volvo v70 2|4 d5 -10|20 000 - 20 499| 81000|Diesel|Automat|Kristianstad|20000|20499|volvo|  v70|
# |2019-03-21 16:38:09|    volvo s70 98 -98|22 000 - 22 499| 14000|Bensin|Manuell| Helsingborg|22000|22499|volvo|  s70|
# |2019-03-21 16:11:14|   volvo t + s80 -99|27 000 - 27 499| 12000|Bensin|Automat|    Perstorp|27000|27499|volvo|    t|
# |2019-03-21 16:05:59|       volvo v40 -01|13 500 - 13 999| 15000|Bensin|Manuell|       Eslöv|13500|13999|volvo|  v40|
# |2019-03-21 15:07:04|volvo s40 2.4 aut...|20 000 - 20 499| 34900|Bensin|Automat| Helsingborg|20000|20499|volvo|  s40|
# |2019-03-21 14:34:45|volvo s60 d5 ny b...|45 000 - 49 999| 22500|Diesel|Automat|    Perstorp|45000|49999|volvo|  s60|
# +-------------------+--------------------+---------------+------+------+-------+------------+-----+-----+-----+-----+
# only showing top 10 rows

# %% [markdown]
# The volvo data frame is converted into a pandas data frame.

# %%
volvo_pandas = volvo.toPandas()

# %% [markdown]
# A new column is added with the name model_num where each model is asigned a number used for coloring of plot.

# %%
volvo_pandas['model_num'] = pandas.factorize(volvo_pandas['model'])[0]

# %%
volvo_pandas.head(5)
# Out:
#                   date                                   title  \
# 0  2019-03-21 21:44:52                     volvo xc70 2.5t -05
# 1  2019-03-21 20:36:07  volvo v90 d5 r-design polestar b&w -17
# 2  2019-03-21 19:45:07              volvo xc70 d4 momentum -14
# 3  2019-03-21 18:21:58                    volvo v50 t5 awd -04
# 4  2019-03-21 17:44:41                    volvo v70 2|4 d5 -10
#
#               dist     price    fuel     gear      location     from       to  \
# 0  27 000 - 27 499   28000.0  Bensin  Manuell         Sjöbo  27000.0  27499.0
# 1    4 000 - 4 499  425000.0  Diesel  Automat          Osby   4000.0   4499.0
# 2    9 000 - 9 499  189900.0  Diesel  Automat         Öster   9000.0   9499.0
# 3  16 000 - 16 499   47000.0  Bensin  Manuell    Simrishamn  16000.0  16499.0
# 4  20 000 - 20 499   81000.0  Diesel  Automat  Kristianstad  20000.0  20499.0
#
#    brand model  model_num
# 0  volvo  xc70          0
# 1  volvo   v90          1
# 2  volvo  xc70          0
# 3  volvo   v50          2
# 4  volvo   v70          3

# %% [markdown]
# Librarys for polting is imported.

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.polynomial.polynomial import polyfit

# %% [markdown]
# A plot of all Volvo cars in the data set are displayed colored based on brand.

# %%
fig, ax = plt.subplots()
scatter = ax.scatter(x = 'from', y = 'price', c = 'model_num', data = volvo_pandas, cmap = 'viridis')
plt.xlabel('Antal mil')
plt.ylabel('Pris sek')
plt.title('Alla privatsålda Volvo på blocket 26/1/19')
plt.show()

# %% [markdown]
# A data frame subset containing only the model v70 is stored as v70.

# %%
v70 = volvo_pandas[volvo_pandas.model == 'v70']

# %% [markdown]
# Removing cars without price and the distance traveled from the data set.

# %%
v70 = v70[v70['from'].notnull()]
v70 = v70[v70['price'].notnull()]

# %% [markdown]
# A regression line is derived.

# %%
b, m = polyfit(v70['from'], v70['price'], 1)

# %% [markdown]
# A plot of all Volvo v70 cars in the data set are displayed with a regression

# %%
fig, ax = plt.subplots()
plt.scatter = ax.scatter(x = 'from', y = 'price', data = v70)
plt.plot(v70['from'], b + m * v70['from'], '-', c = 'r')
plt.xlabel('Antal mil')
plt.ylabel('Pris sek')
plt.title('Alla privatsålda Volvo V70 på blocket 26/1/19')
plt.show()

# %% [markdown]
# ### Part 3
# #### Feb 2, 2019
#
# We want to keep clean the data and make some feature engineering. We want to make a regression model to predict prices based on the scraped data. And when new data is scraped we can find the (according to the model) most undervalued cars. One problem is that the best priced cars will get bought first so our scraped training data is consisting of cars that has been for a sale for a while and might not be priced as well as the ones that imedately gets sold. The model will probably therefore favor cars that recently has been added. To go around this problem scraping should continously be done so that the model could be built on all cars posted on Blocket and not on a sample where the majority of the cars have been for sale a long time.

# %%
import seaborn as sns

# %% [markdown]
# Tyring out a nice looking plot with seaborn.

# %%
sns.lmplot(x = 'from', y = 'price', data = v70)
plt.show()
# Out:
# C:\Users\jonas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# We will create a new feature called `time_since_listing` equal to the current time - `date`.

# %%
from time import gmtime, strftime
current_time = strftime("%Y-%m-%d %H:%M:%S", gmtime())
current_time
# Out:
# '2019-05-10 04:04:37'

# %% [markdown]
# Make sure the dates are on same form.

# %%
df[["date"]].collect()[0][0]
# Out:
# '2019-03-21 21:46:37'

# %% [markdown]
# Add the current time as a constant column to the data farme.

# %%
import pyspark.sql.functions as F
df = df.withColumn("current_time", F.lit(current_time))
df[["current_time"]].show(2)
# Out:
# +-------------------+
# |       current_time|
# +-------------------+
# |2019-05-10 04:04:37|
# |2019-05-10 04:04:37|
# +-------------------+
# only showing top 2 rows

# %% [markdown]
# Subtracting the listing time from the current time and stores is in a colum `time_since_listing` and drop the constant colum `current_time` from the data frame.

# %%
timeFmt = "yyyy-MM-dd HH:mm:ss"
timeDiff = (F.unix_timestamp('current_time', format=timeFmt) - F.unix_timestamp('date', format=timeFmt))

df = df.withColumn("time_since_listing", timeDiff)
df = df.drop("current_time")
df[["time_since_listing"]].show(5)
# Out:
# +------------------+
# |time_since_listing|
# +------------------+
# |           4256280|
# |           4256302|
# |           4256322|
# |           4256351|
# |           4256385|
# +------------------+
# only showing top 5 rows

# %% [markdown]
# We also want to check out the distribution of days on which cars get upploaded. We create a column `Day_of_week`.

# %%
df = df.withColumn("Day_of_week", F.dayofweek(df["date"]))
df[["Day_of_week"]].show(5)
# Out:
# +-----------+
# |Day_of_week|
# +-----------+
# |          5|
# |          5|
# |          5|
# |          5|
# |          5|
# +-----------+
# only showing top 5 rows

# %% [markdown]
# Convert to pandas for plotting and plot.

# %%
pandas_df = df.toPandas()

ax = sns.countplot(x="Day_of_week", data = pandas_df)
ax.set_xticklabels(["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"], rotation='vertical', fontsize=10)
plt.show()

# %%
pandas_df
# Out:
#                      date                                              title  \
# 0     2019-03-21 21:46:37                          cadillac deville cab 1969
# 1     2019-03-21 21:46:15                                peugeot 206 1.4 -05
# 2     2019-03-21 21:45:55                                  audi a3 1|6 l -05
# 3     2019-03-21 21:45:26   seat ateca tsi 150 dsg xcellence överlåtelse -17
# 4     2019-03-21 21:44:52                                volvo xc70 2.5t -05
# 5     2019-03-21 21:43:38     peugeot 307 xr 1.6 nybesiktigad & nyservad -02
# 6     2019-03-21 21:42:29                                     citroen c1 -08
# 7     2019-03-21 21:42:27                        bmw 330 i touring 258hk -06
# 8     2019-03-21 21:41:45                                 golf 5 1.9 tdi -05
# 9     2019-03-21 21:20:09                 saab 9-5 sportkombi 2|3t 185hk -03
# 10    2019-03-21 21:12:39        renault mégane ii 1|6 16ve85 tour sport -07
# 11    2019-03-21 21:10:29                       peugeot 206 sport 1|6 5d -06
# 12    2019-03-21 21:08:20              passat variant 1.8 turbo besiktad -04
# 13    2019-03-21 20:40:22                               bmw 520d touring -06
# 14    2019-03-21 20:36:11  nissan bluebird 2|0 slx veteran extrem lågmil -88
# 15    2019-03-21 20:36:07             volvo v90 d5 r-design polestar b&w -17
# 16    2019-03-21 20:34:05                                   renault clio -03
# 17    2019-03-21 20:26:46                            chevrolet suburban 1967
# 18    2019-03-21 20:21:23     renault espace initiale paris| full| 200hk -15
# 19    2019-03-21 20:15:04      nissan gt-r black edition 550 hk låga mil -14
# 20    2019-03-21 19:49:40    mitsubishi lancer sedan 1|6 instyle 3750mil -07
# 21    2019-03-21 19:46:31                     subaru impreza wrx ev byte -05
# 22    2019-03-21 19:45:07                         volvo xc70 d4 momentum -14
# 23    2019-03-21 19:45:07                            vw golf sportscombi -17
# 24    2019-03-21 19:41:16              volkswagen passat 2.0 tdi 4motion -15
# 25    2019-03-21 19:04:31                   mercedes-benz slk 350| svart -07
# 26    2019-03-21 19:02:05                          ny besiktigad 944 ftt -98
# 27    2019-03-21 19:01:09                                  reservdelsbil -00
# 28    2019-03-21 18:57:05              audi a4 2.0 tdi sport 190 hk - 17 -17
# 29    2019-03-21 18:52:08  volkswagen passat variant gt tdi 170 hk nybes -08
# ...                   ...                                                ...
# 2733  2019-01-19 21:23:15       ny bsekitad mazda 6 . 166 hk bes går bra -05
# 2734  2019-01-19 20:49:06                                        bmw 318 -05
# 2735  2019-01-19 20:21:10       citroën nemo 1.4 hdi dragkrok 10 ev byte -10
# 2736  2019-01-19 19:27:05                           kia carnival 2|9 tdi -04
# 2737  2019-01-19 19:23:05            mercedes-benz vito 111 cdi 2|2 lång -10
# 2738  2019-01-19 18:52:55             skoda yeti 1.2 tsi dsg fulltrustad -10
# 2739  2019-01-19 17:06:02                         mercedes - benz e320 t -04
# 2740  2019-01-19 16:04:36                  ny besiktigad peguet 307 - 06 -06
# 2741  2019-01-19 15:20:55         audi rs6 avant performance 605hk q str -18
# 2742  2019-01-19 15:05:01                         vw caddy 1|6 tdi 102hk -11
# 2743  2019-01-19 14:57:46                          chevrolet c20 1968 pickup
# 2744  2019-01-19 14:34:01                                    iveco daily -10
# 2745  2019-01-19 14:15:14                                  mazda xedos 9 -01
# 2746  2019-01-19 14:14:57      mitsubishi space star1|6 biskta skatta 02 -02
# 2747  2019-01-19 13:10:20                        volvo v70 skatt och bes -09
# 2748  2019-01-19 08:03:40           volvo v50 2.0d ny besiktad toppskick -08
# 2749  2019-01-19 07:27:06                            mercedes benz a 140 -00
# 2750  2019-01-18 19:32:06              saab 9-5 linearsport sp 2|3 turbo -03
# 2751  2019-01-18 18:07:54                      peugeot boxer dh med kran -03
# 2752  2019-01-18 17:15:40                             audi a8 3.0 v6 tdi -16
# 2753  2019-01-18 17:12:23                                     bmw 530 gt -10
# 2754  2019-01-18 16:28:16                             hyundai sonata 2|0 -08
# 2755  2019-01-18 16:16:19                          subaru forester 170hp -99
# 2756  2019-01-18 14:56:13                 volswagen golf v gti 2.0t tfsi -07
# 2757  2019-01-18 14:26:40                    volvo xc70 awd d5 toppskick -06
# 2758  2019-01-18 11:22:22                             honda hrv elegance -16
# 2759  2019-01-18 09:33:00               volvo 945-833 gl/se-pkt dragkrok -93
# 2760  2019-01-18 08:14:46                            volvo 740 16v turbo -88
# 2761  2019-01-18 08:06:22                                volvo 740 turbo -88
# 2762  2019-01-18 07:23:43                  vw passat 2|0 tdi four motion -14
#
#                  dist     price                 fuel     gear        location  \
# 0       3 500 - 3 999  229000.0               Bensin  Automat           Ystad
# 1     10 500 - 10 999   26000.0               Bensin  Manuell            Höör
# 2     23 000 - 23 499   29000.0               Bensin  Manuell         Sydväst
# 3       2 500 - 2 999  225000.0               Bensin  Automat     Helsingborg
# 4     27 000 - 27 499   28000.0               Bensin  Manuell           Sjöbo
# 5     17 500 - 17 999   16000.0               Bensin  Manuell     Helsingborg
# 6       5 000 - 5 499   29500.0               Bensin  Manuell     Helsingborg
# 7     17 500 - 17 999   79500.0               Bensin  Automat          Båstad
# 8     28 000 - 28 499   35900.0               Diesel  Manuell    Östra Göinge
# 9     30 000 - 34 999    8000.0               Bensin  Manuell            Lund
# 10      8 500 - 8 999   19800.0               Bensin  Manuell    Kristianstad
# 11    16 000 - 16 499   19000.0               Bensin  Manuell    Kristianstad
# 12    30 000 - 34 999   13500.0               Bensin  Manuell          Sydost
# 13    29 000 - 29 499   40000.0               Diesel  Manuell          Burlöv
# 14      5 000 - 5 499   44900.0               Bensin  Manuell          Burlöv
# 15      4 000 - 4 499  425000.0               Diesel  Automat            Osby
# 16    19 500 - 19 999    7500.0               Bensin  Manuell        Bromölla
# 17            0 - 499  155000.0               Bensin  Automat   Centralt Norr
# 18      8 500 - 8 999  220000.0               Bensin  Automat          Burlöv
# 19      3 500 - 3 999  625000.0               Bensin  Automat           Ystad
# 20      3 500 - 3 999   42000.0               Bensin  Manuell           Lomma
# 21    11 000 - 11 499   85000.0               Bensin  Manuell           Sjöbo
# 22      9 000 - 9 499  189900.0               Diesel  Automat           Öster
# 23      7 500 - 7 999  185000.0               Bensin  Automat    Kristianstad
# 24      6 500 - 6 999  140000.0               Diesel  Manuell   Centralt Norr
# 25    10 500 - 10 999  149000.0               Bensin  Automat     Helsingborg
# 26    35 000 - 39 999    9500.0               Bensin  Manuell            Lund
# 27    29 500 - 29 999    7500.0               Bensin  Manuell            Höör
# 28      4 500 - 4 999  259000.0               Diesel  Automat          Svalöv
# 29    21 000 - 21 499   39900.0               Diesel  Automat      Trelleborg
# ...               ...       ...                  ...      ...             ...
# 2733  18 000 - 18 499   15000.0               Bensin  Manuell  Centralt Söder
# 2734  23 000 - 23 499   22900.0               Bensin  Manuell  Centralt Söder
# 2735  15 000 - 15 499   34999.0               Diesel  Manuell    Kristianstad
# 2736  25 500 - 25 999    6500.0               Diesel  Manuell   Centralt Norr
# 2737  19 500 - 19 999   52000.0               Diesel  Automat           Öster
# 2738  12 500 - 12 999  109000.0               Bensin  Automat    Kristianstad
# 2739  24 500 - 24 999   33000.0               Bensin  Automat      Landskrona
# 2740  17 000 - 17 499   22000.0               Bensin  Manuell      Hässleholm
# 2741          0 - 499       NaN               Bensin  Automat     Helsingborg
# 2742  18 500 - 18 999   74000.0               Diesel  Manuell            Höör
# 2743    9 500 - 9 999   89000.0               Bensin  Automat        Vellinge
# 2744  17 000 - 17 499   68000.0               Diesel  Automat        Kävlinge
# 2745  14 500 - 14 999   29900.0               Bensin  Automat       Ängelholm
# 2746  27 500 - 27 999    5500.0               Bensin  Manuell  Centralt Söder
# 2747  16 000 - 16 499   69000.0  Miljöbränsle/Hybrid  Manuell      Hässleholm
# 2748  19 000 - 19 499   39900.0               Diesel  Manuell          Burlöv
# 2749  11 000 - 11 499   22900.0               Bensin  Automat    Kristianstad
# 2750  23 000 - 23 499   13000.0               Bensin  Manuell    Kristianstad
# 2751  29 000 - 29 499   24900.0               Diesel  Manuell         Sydväst
# 2752    3 000 - 3 499  485000.0               Diesel  Automat         Sydväst
# 2753  20 000 - 20 499  139500.0               Diesel  Automat         Klippan
# 2754  23 000 - 23 499   33000.0               Diesel  Automat     Helsingborg
# 2755  27 500 - 27 999   15500.0               Bensin  Manuell           Sjöbo
# 2756  18 000 - 18 499   65000.0               Bensin  Automat      Landskrona
# 2757  26 500 - 26 999   49800.0               Diesel  Automat      Trelleborg
# 2758    5 500 - 5 999  135000.0               Diesel  Manuell            Lund
# 2759  30 000 - 34 999   12900.0               Bensin  Manuell            Höör
# 2760  22 000 - 22 499   35000.0               Bensin  Manuell    Kristianstad
# 2761  25 500 - 25 999   30000.0               Bensin  Manuell    Kristianstad
# 2762  10 000 - 10 499  139000.0               Diesel  Manuell     Helsingborg
#
#          from       to          brand       model  time_since_listing  \
# 0      3500.0   3999.0       cadillac     deville             4256280
# 1     10500.0  10999.0        peugeot         206             4256302
# 2     23000.0  23499.0           audi          a3             4256322
# 3      2500.0   2999.0           seat       ateca             4256351
# 4     27000.0  27499.0          volvo        xc70             4256385
# 5     17500.0  17999.0        peugeot         307             4256459
# 6      5000.0   5499.0        citroen          c1             4256528
# 7     17500.0  17999.0            bmw         330             4256530
# 8     28000.0  28499.0           golf           5             4256572
# 9     30000.0  34999.0           saab         9-5             4257868
# 10     8500.0   8999.0        renault      mégane             4258318
# 11    16000.0  16499.0        peugeot         206             4258448
# 12    30000.0  34999.0         passat     variant             4258577
# 13    29000.0  29499.0            bmw        520d             4260255
# 14     5000.0   5499.0         nissan    bluebird             4260506
# 15     4000.0   4499.0          volvo         v90             4260510
# 16    19500.0  19999.0        renault        clio             4260632
# 17        0.0    499.0      chevrolet    suburban             4261071
# 18     8500.0   8999.0        renault      espace             4261394
# 19     3500.0   3999.0         nissan        gt-r             4261773
# 20     3500.0   3999.0     mitsubishi      lancer             4263297
# 21    11000.0  11499.0         subaru     impreza             4263486
# 22     9000.0   9499.0          volvo        xc70             4263570
# 23     7500.0   7999.0             vw        golf             4263570
# 24     6500.0   6999.0     volkswagen      passat             4263801
# 25    10500.0  10999.0  mercedes-benz         slk             4266006
# 26    35000.0  39999.0             ny  besiktigad             4266152
# 27    29500.0  29999.0  reservdelsbil         -00             4266208
# 28     4500.0   4999.0           audi          a4             4266452
# 29    21000.0  21499.0     volkswagen      passat             4266749
# ...       ...      ...            ...         ...                 ...
# 2733  18000.0  18499.0             ny    bsekitad             9524482
# 2734  23000.0  23499.0            bmw         318             9526531
# 2735  15000.0  15499.0        citroën        nemo             9528207
# 2736  25500.0  25999.0            kia    carnival             9531452
# 2737  19500.0  19999.0  mercedes-benz        vito             9531692
# 2738  12500.0  12999.0          skoda        yeti             9533502
# 2739  24500.0  24999.0       mercedes           -             9539915
# 2740  17000.0  17499.0             ny  besiktigad             9543601
# 2741      0.0    499.0           audi         rs6             9546222
# 2742  18500.0  18999.0             vw       caddy             9547176
# 2743   9500.0   9999.0      chevrolet         c20             9547611
# 2744  17000.0  17499.0          iveco       daily             9549036
# 2745  14500.0  14999.0          mazda       xedos             9550163
# 2746  27500.0  27999.0     mitsubishi       space             9550180
# 2747  16000.0  16499.0          volvo         v70             9554057
# 2748  19000.0  19499.0          volvo         v50             9572457
# 2749  11000.0  11499.0       mercedes        benz             9574651
# 2750  23000.0  23499.0           saab         9-5             9617551
# 2751  29000.0  29499.0        peugeot       boxer             9622603
# 2752   3000.0   3499.0           audi          a8             9625737
# 2753  20000.0  20499.0            bmw         530             9625934
# 2754  23000.0  23499.0        hyundai      sonata             9628581
# 2755  27500.0  27999.0         subaru    forester             9629298
# 2756  18000.0  18499.0      volswagen        golf             9634104
# 2757  26500.0  26999.0          volvo        xc70             9635877
# 2758   5500.0   5999.0          honda         hrv             9646935
# 2759  30000.0  34999.0          volvo     945-833             9653497
# 2760  22000.0  22499.0          volvo         740             9658191
# 2761  25500.0  25999.0          volvo         740             9658695
# 2762  10000.0  10499.0             vw      passat             9661254
#
#       Day_of_week
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5
# 5               5
# 6               5
# 7               5
# 8               5
# 9               5
# 10              5
# 11              5
# 12              5
# 13              5
# 14              5
# 15              5
# 16              5
# 17              5
# 18              5
# 19              5
# 20              5
# 21              5
# 22              5
# 23              5
# 24              5
# 25              5
# 26              5
# 27              5
# 28              5
# 29              5
# ...           ...
# 2733            7
# 2734            7
# 2735            7
# 2736            7
# 2737            7
# 2738            7
# 2739            7
# 2740            7
# 2741            7
# 2742            7
# 2743            7
# 2744            7
# 2745            7
# 2746            7
# 2747            7
# 2748            7
# 2749            7
# 2750            6
# 2751            6
# 2752            6
# 2753            6
# 2754            6
# 2755            6
# 2756            6
# 2757            6
# 2758            6
# 2759            6
# 2760            6
# 2761            6
# 2762            6
#
# [2763 rows x 13 columns]

# %%
df.groupBy("fuel").count().show()
# Out:
# +-------------------+-----+
# |               fuel|count|
# +-------------------+-----+
# |             Bensin| 1740|
# |             Diesel|  957|
# |Miljöbränsle/Hybrid|   60|
# |                 El|    6|
# +-------------------+-----+

# %%
df.groupBy("gear").count().show()
# Out:
# +-------+-----+
# |   gear|count|
# +-------+-----+
# |Manuell| 1795|
# |Automat|  968|
# +-------+-----+

# %%
df.groupBy("location").count().show()
# Out:
# +------------+-----+
# |    location|count|
# +------------+-----+
# |     Klippan|   47|
# |        Lund|  143|
# |       Lomma|   36|
# |  Hässleholm|  155|
# |      Sydost|   73|
# |      Skurup|   38|
# |   Tomelilla|   39|
# |    Kävlinge|   43|
# |     Svedala|   42|
# |Kristianstad|  225|
# |Östra Göinge|   30|
# |       Hörby|   52|
# |      Båstad|   22|
# |      Burlöv|   52|
# |    Perstorp|   17|
# |  Trelleborg|  116|
# |       Sjöbo|   36|
# |     Höganäs|   52|
# |    Bromölla|   19|
# |  Landskrona|   95|
# +------------+-----+
# only showing top 20 rows

# %% [markdown]
# End of session Feb 02, 2019.
